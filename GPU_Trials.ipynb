# %%
# !unzip -q colab_export.zip -d work

# %%
# %cd work
# Out:
# /content/work

# %%
# !python colab_train_set.py --arm mlp --dataset yushinito_pooled.jsonl.gz --seeds 10
# Out:
# featurised in 211s: train=84980 val=27844 test=23645
# device=cuda arm=mlp dim=658 max_opts=49 train=84980 val=27844 test=23645
#   parameters/member: 31,681
#   seed 0: val 0.7443  test 0.7455
#   permutation/duplicate invariance: max |score(dup) - score(orig)| = 0.00e+00
#   seed 1: val 0.7365  test 0.7432
#   seed 2: val 0.7398  test 0.7436
#   seed 3: val 0.7429  test 0.7546
#   seed 4: val 0.7431  test 0.7566
#   seed 5: val 0.7361  test 0.7347
#   seed 6: val 0.7413  test 0.7486
#   seed 7: val 0.7372  test 0.7397
#   seed 8: val 0.7491  test 0.7512
#   seed 9: val 0.7471  test 0.7500
#
# ...
# ARM mlp  (10 seeds, 130s)
#   per-seed TEST: mean 0.7468 +- SE 0.0021  [min 0.7347, max 0.7566]
#   ENSEMBLE  train 0.7520   TEST 0.7561   gap -0.0041
#   NOTE: the baseline is the `mlp` arm of THIS sweep, not a historical number.
#         Yushin keeps playing, so the corpus (and therefore the TEST set) grows;
# ...

# %%
# !python colab_train_set.py --arm deep     --dataset yushinito_pooled.jsonl.gz --seeds 10 --baseline 0.7561
# Out:
# device=cuda arm=deep dim=658 max_opts=49 train=84980 val=27844 test=23645
#   parameters/member: 201,729
#   seed 0: val 0.7393  test 0.7418
#   permutation/duplicate invariance: max |score(dup) - score(orig)| = 0.00e+00
#   seed 1: val 0.7454  test 0.7462
#   seed 2: val 0.7487  test 0.7587
#   seed 3: val 0.7388  test 0.7533
#   seed 4: val 0.7504  test 0.7545
#   seed 5: val 0.7472  test 0.7613
#   seed 6: val 0.7498  test 0.7583
#   seed 7: val 0.7470  test 0.7542
#   seed 8: val 0.7509  test 0.7616
#   seed 9: val 0.7508  test 0.7567
#
# ...
# ARM deep  (10 seeds, 238s)
#   per-seed TEST: mean 0.7547 +- SE 0.0020  [min 0.7418, max 0.7616]
#   ENSEMBLE  train 0.7858   TEST 0.7698   gap +0.0160
#   vs baseline 0.7561: +0.0137
#   vs Marnie's Grimmsnarl   n=  8896  TEST 0.7535
#   vs everyone else         n= 10170  TEST 0.7382
#   teacher WON              n= 12725  TEST 0.7452
#   teacher LOST             n= 10920  TEST 0.7984
# ...

# %%
# !python colab_train_set.py --arm deepsets --dataset yushinito_pooled.jsonl.gz --seeds 10 --baseline 0.7561
# Out:
# device=cuda arm=deepsets dim=658 max_opts=49 train=84980 val=27844 test=23645
#   parameters/member: 133,761
#   seed 0: val 0.7511  test 0.7643
#   permutation/duplicate invariance: max |score(dup) - score(orig)| = 0.00e+00
#   seed 1: val 0.7533  test 0.7556
#   seed 2: val 0.7641  test 0.7629
#   seed 3: val 0.7511  test 0.7648
#   seed 4: val 0.7648  test 0.7670
#   seed 5: val 0.7623  test 0.7648
#   seed 6: val 0.7640  test 0.7747
#   seed 7: val 0.7441  test 0.7505
#   seed 8: val 0.7598  test 0.7730
#   seed 9: val 0.7577  test 0.7699
#
# ...
# ARM deepsets  (10 seeds, 255s)
#   per-seed TEST: mean 0.7648 +- SE 0.0023  [min 0.7505, max 0.7747]
#   ENSEMBLE  train 0.7955   TEST 0.7818   gap +0.0137
#   vs baseline 0.7561: +0.0257
#   vs Marnie's Grimmsnarl   n=  8896  TEST 0.7688
#   vs everyone else         n= 10170  TEST 0.7505
#   teacher WON              n= 12725  TEST 0.7581
#   teacher LOST             n= 10920  TEST 0.8094
# ...

# %%
# !python colab_train_set.py --arm setxf    --dataset yushinito_pooled.jsonl.gz --seeds 10 --baseline 0.7561 --layers 2 --d-model 64
# Out:
# device=cuda arm=setxf dim=658 max_opts=49 train=84980 val=27844 test=23645
#   parameters/member: 142,337
#   seed 0: val 0.7635  test 0.7689
#   permutation/duplicate invariance: max |score(dup) - score(orig)| = 0.00e+00
#   seed 1: val 0.7515  test 0.7743
#   seed 2: val 0.7502  test 0.7572
#   seed 3: val 0.7547  test 0.7459
#   seed 4: val 0.7493  test 0.7681
#   seed 5: val 0.7412  test 0.7415
#   seed 6: val 0.7392  test 0.7479
#   seed 7: val 0.7449  test 0.7743
#   seed 8: val 0.7630  test 0.7762
#   seed 9: val 0.7514  test 0.7446
#
# ...
# ARM setxf  (10 seeds, 1290s)
#   per-seed TEST: mean 0.7599 +- SE 0.0044  [min 0.7415, max 0.7762]
#   ENSEMBLE  train 0.8051   TEST 0.7936   gap +0.0114
#   vs baseline 0.7561: +0.0375
#   vs Marnie's Grimmsnarl   n=  8896  TEST 0.7791
#   vs everyone else         n= 10170  TEST 0.7661
#   teacher WON              n= 12725  TEST 0.7746
#   teacher LOST             n= 10920  TEST 0.8158
# ...

# %%
# !python colab_train_set.py --arm mlp --profile ALAKAZAM_MEM --dataset yushinito_pooled.jsonl.gz --seeds 10 --baseline 0.7561
# Out:
# featurised in 230s: train=84980 val=27844 test=23645
# device=cuda arm=mlp dim=818 max_opts=49 train=84980 val=27844 test=23645
#   parameters/member: 39,361
#   seed 0: val 0.7553  test 0.7643
#   permutation/duplicate invariance: max |score(dup) - score(orig)| = 0.00e+00
#   seed 1: val 0.7437  test 0.7470
#   seed 2: val 0.7511  test 0.7611
#   seed 3: val 0.7538  test 0.7567
#   seed 4: val 0.7474  test 0.7332
#   seed 5: val 0.7546  test 0.7543
#   seed 6: val 0.7572  test 0.7577
#   seed 7: val 0.7493  test 0.7595
#   seed 8: val 0.7577  test 0.7628
#   seed 9: val 0.7489  test 0.7524
#
# ...
# ARM mlp  (10 seeds, 153s)
#   per-seed TEST: mean 0.7549 +- SE 0.0029  [min 0.7332, max 0.7643]
#   ENSEMBLE  train 0.7665   TEST 0.7692   gap -0.0027
#   vs baseline 0.7561: +0.0131
#   vs Marnie's Grimmsnarl   n=  8896  TEST 0.7520
#   vs everyone else         n= 10170  TEST 0.7413
#   teacher WON              n= 12725  TEST 0.7438
#   teacher LOST             n= 10920  TEST 0.7988
# ...
