# %%
# !unzip -q colab_export.zip -d work

# %%
# %cd work
# Out:
# /content/work

# %%
# !python colab_train_set.py --arm mlp --dataset yushinito_pooled.jsonl.gz --seeds 10
# Out:
# device=cuda arm=mlp dim=658 max_opts=49 train=84980 val=27844 test=23645
#   parameters/member: 31,681
#   seed 0: val 0.7443  test 0.7455  (best@ep18, ran 24)
#   permutation/duplicate invariance: max |score(dup) - score(orig)| = 0.00e+00
#   seed 1: val 0.7365  test 0.7432  (best@ep13, ran 19)
#   seed 2: val 0.7398  test 0.7436  (best@ep16, ran 22)
#   seed 3: val 0.7429  test 0.7546  (best@ep42, ran 48)
#   seed 4: val 0.7431  test 0.7566  (best@ep35, ran 41)
#   seed 5: val 0.7361  test 0.7347  (best@ep11, ran 17)
#   seed 6: val 0.7413  test 0.7486  (best@ep27, ran 33)
#   seed 7: val 0.7372  test 0.7397  (best@ep14, ran 20)
#   seed 8: val 0.7491  test 0.7512  (best@ep25, ran 31)
#   seed 9: val 0.7471  test 0.7500  (best@ep18, ran 24)
#
# ...
# ARM mlp  (10 seeds, 136s)
#   per-seed TEST: mean 0.7468 +- SE 0.0021  [min 0.7347, max 0.7566]
#   ENSEMBLE  train 0.7520   TEST 0.7561   gap -0.0041
#   ensemble curve (first-k members):
#     k=1   TEST 0.7455
#     k=2   TEST 0.7479
# ...

# %%
# !python colab_train_set.py --arm setxf --dataset yushinito_pooled.jsonl.gz --seeds 10 --baseline 0.7561 --d-model 64 --layers 2
# Out:
# device=cuda arm=setxf dim=658 max_opts=49 train=84980 val=27844 test=23645
#   parameters/member: 142,337
#   seed 0: val 0.7587  test 0.7706  (best@ep12, ran 18)
#   permutation/duplicate invariance: max |score(dup) - score(orig)| = 0.00e+00
#   seed 1: val 0.7592  test 0.7701  (best@ep8, ran 14)
#   seed 2: val 0.7563  test 0.7666  (best@ep12, ran 18)
#   seed 3: val 0.7591  test 0.7619  (best@ep14, ran 20)
#   seed 4: val 0.7615  test 0.7677  (best@ep7, ran 13)
#   seed 5: val 0.7638  test 0.7503  (best@ep6, ran 12)
#   seed 6: val 0.7590  test 0.7759  (best@ep16, ran 22)
#   seed 7: val 0.7568  test 0.7721  (best@ep12, ran 18)
#   seed 8: val 0.7561  test 0.7727  (best@ep12, ran 18)
#   seed 9: val 0.7569  test 0.7623  (best@ep4, ran 10)
#
# ...
# ARM setxf  (10 seeds, 708s)
#   per-seed TEST: mean 0.7670 +- SE 0.0023  [min 0.7503, max 0.7759]
#   ENSEMBLE  train 0.8372   TEST 0.7988   gap +0.0384
#   ensemble curve (first-k members):
#     k=1   TEST 0.7706
#     k=2   TEST 0.7852
# ...

# %%
# !python colab_train_set.py --arm setxf2 --dataset yushinito_pooled.jsonl.gz --seeds 10 --baseline 0.7561 --d-model 128 --layers 3 --warmup 3
# Out:
# device=cuda arm=setxf2 dim=658 max_opts=49 train=84980 val=27844 test=23645
#   parameters/member: 658,177
#   seed 0: val 0.7633  test 0.7808  (best@ep11, ran 17)
#   permutation/duplicate invariance: max |score(dup) - score(orig)| = 0.00e+00
#   seed 1: val 0.7646  test 0.7717  (best@ep9, ran 15)
#   seed 2: val 0.7709  test 0.7645  (best@ep12, ran 18)
#   seed 3: val 0.7620  test 0.7500  (best@ep10, ran 16)
#   seed 4: val 0.7550  test 0.7852  (best@ep10, ran 16)
#   seed 5: val 0.7590  test 0.7794  (best@ep9, ran 15)
#   seed 6: val 0.7639  test 0.7737  (best@ep12, ran 18)
#   seed 7: val 0.7606  test 0.7525  (best@ep6, ran 12)
#   seed 8: val 0.7571  test 0.7632  (best@ep7, ran 13)
#   seed 9: val 0.7591  test 0.7783  (best@ep9, ran 15)
#
# ...
# ARM setxf2  (10 seeds, 1752s)
#   per-seed TEST: mean 0.7699 +- SE 0.0038  [min 0.7500, max 0.7852]
#   ENSEMBLE  train 0.8386   TEST 0.8044   gap +0.0342
#   ensemble curve (first-k members):
#     k=1   TEST 0.7808
#     k=2   TEST 0.7964
# ...

# %%
# !python colab_train_set.py --arm setxf2 --dataset yushinito_pooled.jsonl.gz --seeds 10 --baseline 0.7561 --d-model 128 --layers 3 --warmup 3 --use-cross
# Out:
# device=cuda arm=setxf2 dim=658 max_opts=49 train=84980 val=27844 test=23645
#   parameters/member: 729,345
#   seed 0: val 0.7789  test 0.7835  (best@ep7, ran 13)
#   permutation/duplicate invariance: max |score(dup) - score(orig)| = 0.00e+00
#   seed 1: val 0.7715  test 0.7736  (best@ep8, ran 14)
#   seed 2: val 0.7629  test 0.7720  (best@ep9, ran 15)
#   seed 3: val 0.7715  test 0.7756  (best@ep6, ran 12)
#   seed 4: val 0.7686  test 0.7794  (best@ep9, ran 15)
#   seed 5: val 0.7545  test 0.7611  (best@ep5, ran 11)
#   seed 6: val 0.7693  test 0.7570  (best@ep10, ran 16)
#   seed 7: val 0.7584  test 0.7720  (best@ep8, ran 14)
#   seed 8: val 0.7591  test 0.7764  (best@ep6, ran 12)
#   seed 9: val 0.7618  test 0.7665  (best@ep6, ran 12)
#
# ...
# ARM setxf2  (10 seeds, 1586s)
#   per-seed TEST: mean 0.7717 +- SE 0.0026  [min 0.7570, max 0.7835]
#   ENSEMBLE  train 0.8371   TEST 0.8008   gap +0.0364
#   ensemble curve (first-k members):
#     k=1   TEST 0.7835
#     k=2   TEST 0.7910
# ...

# %%
# !python colab_train_set.py --arm deepsets --dataset yushinito_pooled.jsonl.gz --seeds 10 --baseline 0.7561
# Out:
# device=cuda arm=deepsets dim=658 max_opts=49 train=84980 val=27844 test=23645
#   parameters/member: 133,761
#   seed 0: val 0.7511  test 0.7643  (best@ep7, ran 13)
#   permutation/duplicate invariance: max |score(dup) - score(orig)| = 0.00e+00
#   seed 1: val 0.7533  test 0.7556  (best@ep7, ran 13)
#   seed 2: val 0.7641  test 0.7629  (best@ep10, ran 16)
#   seed 3: val 0.7511  test 0.7648  (best@ep9, ran 15)
#   seed 4: val 0.7648  test 0.7670  (best@ep13, ran 19)
#   seed 5: val 0.7623  test 0.7648  (best@ep9, ran 15)
#   seed 6: val 0.7640  test 0.7747  (best@ep25, ran 31)
#   seed 7: val 0.7441  test 0.7505  (best@ep4, ran 10)
#   seed 8: val 0.7598  test 0.7730  (best@ep16, ran 22)
#   seed 9: val 0.7577  test 0.7699  (best@ep15, ran 21)
#
# ...
# ARM deepsets  (10 seeds, 263s)
#   per-seed TEST: mean 0.7648 +- SE 0.0023  [min 0.7505, max 0.7747]
#   ENSEMBLE  train 0.7955   TEST 0.7818   gap +0.0137
#   ensemble curve (first-k members):
#     k=1   TEST 0.7643
# ...
